# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# !mkdir -p gdrive/My\ Drive/임베/project
# %cd gdrive/My\ Drive/임베/project
# Out:
# /content/gdrive/My Drive/임베/project

# %%
# !git clone https://github.com/1207koo/ESAPR.git
# Out:
# fatal: destination path 'ESAPR' already exists and is not an empty directory.

# %%
# %cd ESAPR/
# !ls
# Out:
# /content/gdrive/My Drive/임베/project/ESAPR
# analyze_table  dataloaders  __init__.py  options	   templates
# communicator   datasets     loggers	 __pycache__	   top
# config.py      experiments  main.py	 README.md	   trainers
# Data	       gdrive	    models	 requirements.txt  utils.py

# %%
# !nvidia-smi
# Out:
# Fri Dec 18 07:15:35 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 215kB 12.5MB/s
# ...
#      |████████████████████████████████| 773.1MB 22kB/s
# ...
#      |████████████████████████████████| 61kB 9.8MB/s
# ...
#      |████████████████████████████████| 10.4MB 43.2MB/s
# ...
#      |████████████████████████████████| 20.4MB 1.3MB/s
# ...
#      |████████████████████████████████| 1.4MB 52.1MB/s
# ...
#      |████████████████████████████████| 276kB 58.3MB/s
# ...
#      |████████████████████████████████| 962kB 46.1MB/s
# ...
#      |████████████████████████████████| 2.6MB 47.0MB/s
# ...
#      |████████████████████████████████| 71kB 11.0MB/s
# ...
#      |████████████████████████████████| 163kB 61.6MB/s
# ...
#      |████████████████████████████████| 102kB 14.8MB/s
# ...
#      |████████████████████████████████| 102kB 14.7MB/s
# ...
#      |████████████████████████████████| 133kB 54.1MB/s
# ...
#      |████████████████████████████████| 256kB 49.9MB/s
# ...
#      |████████████████████████████████| 71kB 11.2MB/s
# ...
#      |████████████████████████████████| 184kB 64.3MB/s
# ...

# %%
# !git pull https://github.com/1207koo/ESAPR.git
# Out:
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 40 (delta 31), reused 26 (delta 17), pack-reused 0
# Unpacking objects: 100% (40/40), done.
# From https://github.com/1207koo/ESAPR
#  * branch            HEAD       -> FETCH_HEAD
# Updating a502d43..2d4028b
# Fast-forward
#  dataloaders/vae.py         | 5 +++++
#  options/training_parser.py | 1 +
#  templates/train_vae.yaml   | 3 ++-
#  3 files changed, 8 insertions(+), 1 deletion(-)

# %%
# !python3 main.py --templates train_vae
# Out:
# Removing local test export root experiments/test/vae
# Export root experiments/test/vae
# Already preprocessed. Skip preprocessing
# Negatives samples exist. Loading.
# Negatives samples exist. Loading.
# Epoch 0, loss 59.963 : 100% 241/241 [00:24<00:00,  9.82it/s]
# Val: N@1 0.1637, N@5 0.2976, N@10 0.3432, N@20 0.3770, N@50 0.4125, N@100 0.4325, R@1 0.1637, R@5 0.4224, R@10 0.5638, R@20 0.6973, R@50 0.8751, R@100 0.9982: 100% 12/12 [00:02<00:00,  5.62it/s]
# Update Best NDCG@10 Model at 0
# Epoch 1, loss 57.809 : 100% 241/241 [00:26<00:00,  9.25it/s]
# Val: N@1 0.1707, N@5 0.3135, N@10 0.3570, N@20 0.3900, N@50 0.4243, N@100 0.4429, R@1 0.1707, R@5 0.4461, R@10 0.5805, R@20 0.7112, R@50 0.8832, R@100 0.9978: 100% 12/12 [00:01<00:00,  6.45it/s]
# Update Best NDCG@10 Model at 1
# Epoch 2, loss 57.353 : 100% 241/241 [00:26<00:00,  9.12it/s]
# ...

# %%
# !mv ./experiments/test/vae/ ../files/

# %%
# !python3 main.py --templates train_vae --dataset_code ml-20m --train_window 128 --saturation_wait_epochs 16
# Out:
# Export root experiments/test/vae
# Already preprocessed. Skip preprocessing
# Negatives samples exist. Loading.
# Negatives samples exist. Loading.
# Epoch 0, loss 61.567 : 100% 379/379 [00:55<00:00,  6.80it/s]
# Val: N@1 0.1458, N@5 0.2670, N@10 0.3139, N@20 0.3538, N@50 0.3925, N@100 0.4120, R@1 0.1458, R@5 0.3827, R@10 0.5281, R@20 0.6855, R@50 0.8795, R@100 0.9991: 100% 271/271 [00:50<00:00,  5.38it/s]
# Update Best NDCG@10 Model at 0
# Epoch 1, loss 58.485 : 100% 379/379 [00:59<00:00,  6.38it/s]
# Val: N@1 0.1712, N@5 0.3005, N@10 0.3461, N@20 0.3841, N@50 0.4198, N@100 0.4372, R@1 0.1712, R@5 0.4226, R@10 0.5637, R@20 0.7138, R@50 0.8930, R@100 0.9995: 100% 271/271 [00:51<00:00,  5.28it/s]
# Update Best NDCG@10 Model at 1
# Epoch 2, loss 58.031 : 100% 379/379 [01:00<00:00,  6.28it/s]
# ...

# %%
# !mv ./experiments/test/vae/ ../files/ml_20m/
